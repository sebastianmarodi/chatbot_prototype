# %% [markdown]
# ### Language Model Setup

# %%
import openai
import os

openai.api_key =  os.getenv('OPENAI_API_KEY')

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(temperature=0.0, model_name='gpt-3.5-turbo')

# %% [markdown]
# ### Tokenizer Setup

# %%
import tiktoken 
tiktoken.encoding_for_model('gpt-3.5-turbo')
# Out:
# <Encoding 'cl100k_base'>

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

# %%
from langchain.embeddings.openai import OpenAIEmbeddings

model_name = 'text-embedding-ada-002'

embed = OpenAIEmbeddings(
    model=model_name,
    openai_api_key=os.environ['OPENAI_API_KEY']
)

# %%
text_examples = ["I am a text example", 
                 "I am another text example"]

# %%
result = embed.embed_documents(text_examples)

# %%
len(result[0])
# Out:
# 1536

# %% [markdown]
# ### Importing Raw Datasets

# %%
kegg_medicus_drug = 'raw_datasets/kegg_medicus_drug_en.csv'
kegg_medicus_disease = 'raw_datasets/kegg_medicus_disease_en.csv'
kegg_medicus_dgroup = 'raw_datasets/kegg_medicus_dgroup_en.csv'
kegg_medicus_environ = 'raw_datasets/kegg_medicus_environ_en.csv'
kegg_medicus_network = 'raw_datasets/kegg_medicus_network.csv'
kegg_medicus_variant = 'raw_datasets/kegg_medicus_variant.csv'

# %%
import pandas as pd

raw_drug_df = pd.read_csv(kegg_medicus_drug)
raw_disease_df = pd.read_csv(kegg_medicus_disease)
raw_dgroup_df = pd.read_csv(kegg_medicus_dgroup)
raw_environ_df = pd.read_csv(kegg_medicus_environ)
raw_network_df = pd.read_csv(kegg_medicus_network)
raw_variant_df = pd.read_csv(kegg_medicus_variant)

# %% [markdown]
# ### Data Cleaning & Preprocessing

# %%
# empty variable for preprocessing function
row_to_dict = None

# %%
preprocessed_datasets = []

# %%
def convert_dataframe_to_list(df):
    result_list = df.apply(row_to_dict, axis=1).tolist()
    return result_list

# %% [markdown]
# #### Kegg Medicus Drug Data Preprocessing

# %%
raw_drug_df.head()
# Out:
#   entry_id classification                                               name  \
# 0   D00001           Drug  Water (JP18/USP);\nPurified water (JP18);\nPur...
# 1   D00002           Drug  Nadide (JAN/USAN/INN);\nNicotinamide adenine d...
# 2   D00003           Drug                                  Oxygen (JP18/USP)
# 3   D00004           Drug    Carbon dioxide (JP18/USP);\nCarbon dioxide (TN)
# 4   D00005           Drug  Flavin adenine dinucleotide (JAN);\nAdeflavin ...
#
#   component        formula  exact_mass  mol_weight   image sequence  \
# 0       NaN            H2O     18.0106     18.0153  D00001      NaN
# 1       NaN  C21H28N7O14P2    664.1169    664.4330  D00002      NaN
# 2       NaN             O2     31.9898     31.9988  D00003      NaN
# 3       NaN            CO2     43.9898     44.0095  D00004      NaN
# 4       NaN  C27H33N9O15P2    785.1571    785.5497  D00005      NaN
#
#   sequence type  ...                                     dblinks_w_link  \
# 0           NaN  ...  CAS<a href="https://identifiers.org/cas:7732-1...
# 1           NaN  ...  CAS<a href="https://identifiers.org/cas:53-84-...
# 2           NaN  ...  CAS<a href="https://identifiers.org/cas:7782-4...
# 3           NaN  ...  CAS<a href="https://identifiers.org/cas:124-38...
# 4           NaN  ...  CAS<a href="https://identifiers.org/cas:146-14...
#
#                           comment_w_link interaction_w_link target_w_link  \
# 0                                    NaN                NaN           NaN
# 1  Antagonist (to alcohol and narcotics)                NaN           NaN
# 2                                    NaN                NaN           NaN
# 3                                    NaN                NaN           NaN
# 4            Coenzyme form of vitamin B2                NaN           NaN
#
#   source_w_link metabolism_w_link sequence_w_link component_w_link  \
# 0           NaN               NaN             NaN              NaN
# 1           NaN               NaN             NaN              NaN
# 2           NaN               NaN             NaN              NaN
# 3           NaN               NaN             NaN              NaN
# 4           NaN               NaN             NaN              NaN
#
#   class_w_link raw_entry_id
# 0          NaN       D00001
# 1          NaN       D00002
# 2          NaN       D00003
# 3          NaN       D00004
# 4          NaN       D00005
#
# [5 rows x 39 columns]

# %%
raw_drug_df.groupby('classification')['classification'].nunique()
# Out:
# classification
# Crude Drug      1
# Drug            1
# Formula Drug    1
# Mixture Drug    1
# Name: classification, dtype: int64

# %%
raw_drug_df.isna().sum()
# Out:
# entry_id                  0
# classification            0
# name                      1
# component             10645
# formula                2296
# exact_mass             2658
# mol_weight             2658
# image                     0
# sequence              11227
# sequence type         11225
# source                11325
# class                  6430
# remark                 4109
# efficacy                 24
# disease               10516
# comment                5738
# target                 5507
# metabolism            10733
# interaction           11591
# db_links                244
# kcf                    3139
# atom                   3139
# bond                   3139
# bracket               10980
# original              10986
# repeat                10986
# disease_w_link        10522
# remark_w_link          4109
# efficacy_w_link       11938
# dblinks_w_link          244
# comment_w_link         5738
# interaction_w_link     6208
# target_w_link          5507
# source_w_link         11325
# metabolism_w_link     10733
# sequence_w_link       11938
# component_w_link      10645
# class_w_link           6430
# raw_entry_id              0
# dtype: int64

# %%
exclude = ['component', 'sequence', 'source', 'db_links', 'sequence type', 
           'dblinks_w_link', 'comment_w_link', 'target_w_link', 'disease', 'disease_w_link',
           'remark_w_link', 'image', 'raw_entry_id', 'class', 'original', 'repeat',
           'efficacy_w_link','source_w_link','metabolism_w_link','sequence_w_link',
            'interaction_w_link','component_w_link','class_w_link', 'interaction','kcf','atom', 'bond',
            'bracket', 'remark','metabolism','target']
clean_drug_df = raw_drug_df[[col for col in raw_drug_df.columns if col not in exclude]]

# %%
clean_drug_df.columns
# Out:
# Index(['entry_id', 'classification', 'name', 'formula', 'exact_mass',
#        'mol_weight', 'efficacy', 'comment'],
#       dtype='object')

# %%
clean_drug_df.head()
# Out:
#   entry_id classification                                               name  \
# 0   D00001           Drug  Water (JP18/USP);\nPurified water (JP18);\nPur...
# 1   D00002           Drug  Nadide (JAN/USAN/INN);\nNicotinamide adenine d...
# 2   D00003           Drug                                  Oxygen (JP18/USP)
# 3   D00004           Drug    Carbon dioxide (JP18/USP);\nCarbon dioxide (TN)
# 4   D00005           Drug  Flavin adenine dinucleotide (JAN);\nAdeflavin ...
#
#          formula  exact_mass  mol_weight                    efficacy  \
# 0            H2O     18.0106     18.0153  Pharmaceutic aid (solvent)
# 1  C21H28N7O14P2    664.1169    664.4330                    Coenzyme
# 2             O2     31.9898     31.9988               Medical gases
# 3            CO2     43.9898     44.0095               Medical gases
# 4  C27H33N9O15P2    785.1571    785.5497     Supplement (vitamin B2)
#
#                                  comment
# 0                                    NaN
# 1  Antagonist (to alcohol and narcotics)
# 2                                    NaN
# 3                                    NaN
# 4            Coenzyme form of vitamin B2

# %%
#1
def row_to_dict(row):
    entry_id = row['entry_id']
    name = row['name']
    efficacy = row['efficacy']
    comment = row['comment']
    formula = row['formula']
    exact_mass = row['exact_mass']
    mol_weight = row['mol_weight']
    classification = row['classification']
    text = f"name: {name}; formula: {formula}; efficacy: {efficacy}; comment: {comment}"
    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "name": name,
                "text": text,
                "classification": classification,
                "formula": formula,
                "exact mass": exact_mass,
                "mol_weight": mol_weight
            }
        }

    return output_dict

# %%
drugs_preprocess = convert_dataframe_to_list(clean_drug_df)
print(len(drugs_preprocess))
drugs_preprocess[0]
# Out:
# 11938
# {'id': 'D00001',
#  'input': 'name: Water (JP18/USP);\nPurified water (JP18);\nPurified water in containers (JP18);\nWater, purified (USP);\nSterile purified water in containers (JP18);\nWater for injection (JP18);\nWater for injection in containers (JP18);\nSterile water (TN); formula: H2O; efficacy: Pharmaceutic aid (solvent); comment: nan',
#  'metadata': {'name': 'Water (JP18/USP);\nPurified water (JP18);\nPurified water in containers (JP18);\nWater, purified (USP);\nSterile purified water in containers (JP18);\nWater for injection (JP18);\nWater for injection in containers (JP18);\nSterile water (TN)',
#   'text': 'name: Water (JP18/USP);\nPurified water (JP18);\nPurified water in containers (JP18);\nWater, purified (USP);\nSterile purified water in containers (JP18);\nWater for injection (JP18);\nWater for injection in containers (JP18);\nSterile water (TN); formula: H2O; efficacy: Pharmaceutic aid (solvent); comment: nan',
#   'classification': 'Drug',
#   'formula': 'H2O',
#   'exact mass': 18.0106,
#   'mol_weight': 18.0153}}

# %%
drugs_df = pd.DataFrame(drugs_preprocess)
preprocessed_datasets.append(drugs_df)
print(drugs_df.shape)
drugs_df.head()
# Out:
# (11938, 3)
#        id                                              input  \
# 0  D00001  name: Water (JP18/USP);\nPurified water (JP18)...
# 1  D00002  name: Nadide (JAN/USAN/INN);\nNicotinamide ade...
# 2  D00003  name: Oxygen (JP18/USP); formula: O2; efficacy...
# 3  D00004  name: Carbon dioxide (JP18/USP);\nCarbon dioxi...
# 4  D00005  name: Flavin adenine dinucleotide (JAN);\nAdef...
#
#                                             metadata
# 0  {'name': 'Water (JP18/USP);
# Purified water (JP...
# 1  {'name': 'Nadide (JAN/USAN/INN);
# Nicotinamide ...
# 2  {'name': 'Oxygen (JP18/USP)', 'text': 'name: O...
# 3  {'name': 'Carbon dioxide (JP18/USP);
# Carbon di...
# 4  {'name': 'Flavin adenine dinucleotide (JAN);
# A...

# %% [markdown]
# #### Kegg Medicus Disease Data Preprocessing

# %%
raw_disease_df.head()
# Out:
#     ENTRY                                               NAME  \
# 0  H00001  B-cell acute lymphoblastic leukemia;\n B-cell ...
# 1  H00002  T-cell acute lymphoblastic leukemia;\n T-cell ...
# 2  H00003                             Acute myeloid leukemia
# 3  H00004                           Chronic myeloid leukemia
# 4  H00005                       Chronic lymphocytic leukemia
#
#                                             SUBGROUP  \
# 0  Philadelphia chromosome positive acute lymphob...
# 1                      T-cell lymphoblastic lymphoma
# 2           Acute promyelocytic leukemia [DS:H02542]
# 3                                                NaN
# 4                                                NaN
#
#                            SUPERGRP  \
# 0  Non-Hodgkin lymphoma [DS:H02418]
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4  Non-Hodgkin lymphoma [DS:H02418]
#
#                                          DESCRIPTION CATEGORY  \
# 0  Acute lymphocytic leukemia (ALL) is a clonal s...   Cancer
# 1  Acute lymphocytic leukemia (ALL) is a clonal s...   Cancer
# 2  Acute myeloid leukemia (AML) is a disease that...   Cancer
# 3  Chronic myeloid leukemia (CML) is a clonal mye...   Cancer
# 4  Chronic lymphocytic leukemia (CLL) is caused b...   Cancer
#
#                              NETWORK  \
# 0                                NaN
# 1                                NaN
# 2    nt06275  Acute myeloid leukemia
# 3  nt06276  Chronic myeloid leukemia
# 4                                NaN
#
#                                                 GENE PATHOGEN ENV_FACTOR  ...  \
# 0  BCR-ABL (translocation) [HSA:25] [KO:K06619]\n...      NaN        NaN  ...
# 1  NOTCH1 (mutation) [HSA:4851] [KO:K02599]\n TAL...      NaN        NaN  ...
# 2  PML-RARalpha (translocation) [HSA:5371] [KO:K1...      NaN        NaN  ...
# 3  BCR-ABL (translocation) [HSA:613 25] [KO:K0887...      NaN        NaN  ...
# 4  Bcl-2 (overexpression) [HSA:596] [KO:K02161]\n...      NaN        NaN  ...
#
#                                     DESCRIPTION_link  \
# 0  Acute lymphocytic leukemia (ALL) is a clonal s...
# 1  Acute lymphocytic leukemia (ALL) is a clonal s...
# 2  Acute myeloid leukemia (AML) is a disease that...
# 3  Chronic myeloid leukemia (CML) is a clonal mye...
# 4  Chronic lymphocytic leukemia (CLL) is caused b...
#
#                                         NETWORK_link  \
# 0                                                NaN
# 1                                                NaN
# 2  <a href="https://www.kegg.jp/network/nt06275">...
# 3  <a href="https://www.kegg.jp/network/nt06276">...
# 4                                                NaN
#
#                                            GENE_link PATHOGEN_link  \
# 0  BCR-ABL (translocation) [HSA:<a href="https://...           NaN
# 1  NOTCH1 (mutation) [HSA:<a href="https://www.ge...           NaN
# 2  PML-RARalpha (translocation) [HSA:<a href="htt...           NaN
# 3  BCR-ABL (translocation) [HSA:<a href="https://...           NaN
# 4  Bcl-2 (overexpression) [HSA:<a href="https://w...           NaN
#
#   ENV_FACTOR_link                                    CARCINOGEN_link  \
# 0             NaN  *Thorium-232 and its decay products, administe...
# 1             NaN  *Thorium-232 and its decay products, administe...
# 2             NaN  Benzene [CPD:<a href="https://www.genome.jp/db...
# 3             NaN  1,3-Butadiene [CPD:<a href="https://www.genome...
# 4             NaN  1,3-Butadiene [CPD:<a href="https://www.genome...
#
#                                            DRUG_link COMMENT_link  \
# 0  Cyclophosphamide [DR:<a href="https://www.geno...          NaN
# 1  Cyclophosphamide [DR:<a href="https://www.geno...          NaN
# 2  Cyclophosphamide [DR:<a href="https://www.geno...          NaN
# 3  Busulfan [DR:<a href="https://www.genome.jp/db...          NaN
# 4  Cyclophosphamide [DR:<a href="https://www.geno...          NaN
#
#                                         DBLINKS_link  \
# 0  ICD-11: 2A70\n ICD-10: C83.5 C91.0\n MeSH: <a ...
# 1  ICD-11: 2A71\n ICD-10: C83.5 C91.0\n MeSH: <a ...
# 2  ICD-11: 2A60\n ICD-10: C92.0\n MeSH: <a href="...
# 3  ICD-11: 2A20.0\n ICD-10: C92.1\n MeSH: <a href...
# 4  ICD-11: 2A82.0\n ICD-10: C91.1\n MeSH: <a href...
#
#                                       REFERENCE_link
# 0  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 1  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 2  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 3  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 4  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
#
# [5 rows x 28 columns]

# %%
raw_disease_df.shape
# Out:
# (2577, 28)

# %%
raw_disease_df.isna().sum()
# Out:
# ENTRY                  0
# NAME                   0
# SUBGROUP            2168
# SUPERGRP            1874
# DESCRIPTION            0
# CATEGORY               0
# NETWORK             2400
# GENE                 516
# PATHOGEN            2211
# ENV_FACTOR          2503
# CARCINOGEN          2537
# DRUG                2119
# COMMENT             2145
# DBLINKS               35
# REFERENCE              3
# ENTRY_link             0
# SUBGROUP_link       2168
# SUPERGRP_link       1874
# DESCRIPTION_link       0
# NETWORK_link        2400
# GENE_link            516
# PATHOGEN_link       2211
# ENV_FACTOR_link     2503
# CARCINOGEN_link     2537
# DRUG_link           2119
# COMMENT_link        2145
# DBLINKS_link          35
# REFERENCE_link         3
# dtype: int64

# %%
exclude = ['SUBGROUP', 'SUPERGRP', 'NETWORK', 'ENTRY_link',
           'SUBGROUP_link', 'SUPERGRP_link', 'DESCRIPTION_link',
           'NETWORK_link', 'GENE_link', 'PATHOGEN_link', 'ENV_FACTOR_link',
           'CARCINOGEN_link', 'DRUG_link', 'COMMENT_link','DBLINKS_link',
           'REFERENCE_link', 'DBLINKS', 'REFERENCE']
clean_disease_df = raw_disease_df[[col for col in raw_disease_df.columns if col not in exclude]]
clean_disease_df.head()
# Out:
#     ENTRY                                               NAME  \
# 0  H00001  B-cell acute lymphoblastic leukemia;\n B-cell ...
# 1  H00002  T-cell acute lymphoblastic leukemia;\n T-cell ...
# 2  H00003                             Acute myeloid leukemia
# 3  H00004                           Chronic myeloid leukemia
# 4  H00005                       Chronic lymphocytic leukemia
#
#                                          DESCRIPTION CATEGORY  \
# 0  Acute lymphocytic leukemia (ALL) is a clonal s...   Cancer
# 1  Acute lymphocytic leukemia (ALL) is a clonal s...   Cancer
# 2  Acute myeloid leukemia (AML) is a disease that...   Cancer
# 3  Chronic myeloid leukemia (CML) is a clonal mye...   Cancer
# 4  Chronic lymphocytic leukemia (CLL) is caused b...   Cancer
#
#                                                 GENE PATHOGEN ENV_FACTOR  \
# 0  BCR-ABL (translocation) [HSA:25] [KO:K06619]\n...      NaN        NaN
# 1  NOTCH1 (mutation) [HSA:4851] [KO:K02599]\n TAL...      NaN        NaN
# 2  PML-RARalpha (translocation) [HSA:5371] [KO:K1...      NaN        NaN
# 3  BCR-ABL (translocation) [HSA:613 25] [KO:K0887...      NaN        NaN
# 4  Bcl-2 (overexpression) [HSA:596] [KO:K02161]\n...      NaN        NaN
#
#                                           CARCINOGEN  \
# 0  *Thorium-232 and its decay products, administe...
# 1  *Thorium-232 and its decay products, administe...
# 2  Benzene [CPD:C01407]\n 1,4-Butanediol dimethan...
# 3       1,3-Butadiene [CPD:C16450]\n Rubber industry
# 4  1,3-Butadiene [CPD:C16450]\n Ethylene oxide [C...
#
#                                                 DRUG COMMENT
# 0  Cyclophosphamide [DR:D00287]\n Methotrexate [D...     NaN
# 1  Cyclophosphamide [DR:D00287]\n Methotrexate [D...     NaN
# 2  Cyclophosphamide [DR:D00287]\n Thioguanine [DR...     NaN
# 3  Busulfan [DR:D00248]\n Thioguanine [DR:D06109]...     NaN
# 4  Cyclophosphamide [DR:D00287]\n Chlorambucil [D...     NaN

# %%
#2
def row_to_dict(row):
    entry_id = row['ENTRY']
    name = row['NAME']
    description = row['DESCRIPTION']
    comment = row['COMMENT']
    category = row['CATEGORY']
    gene = row['GENE']
    pathogen = row['PATHOGEN']
    env_factor = row['ENV_FACTOR']
    carcinogen = row['CARCINOGEN']
    drug = row['DRUG']
    text = f"name: {name}; category: {category}; description: {description}; drug: {drug}"

    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "name": name,
                "text": text,
                "gene": gene,
                "pathogen": pathogen,
                "env_factor": env_factor,
                "carcinogen": carcinogen,
                "drug": drug,
                "comment": comment,
            }
        }

    return output_dict

# %%
disease_preprocess = convert_dataframe_to_list(clean_disease_df)
print(len(disease_preprocess))
disease_preprocess[1]
# Out:
# 2577
# {'id': 'H00002',
#  'input': 'name: T-cell acute lymphoblastic leukemia;\n T-cell acute lymphocytic leukemia; category: Cancer; description: Acute lymphocytic leukemia (ALL) is a clonal stem cell malignancy of excessive lymphoblast proliferation. It is now understood that ALL and lymphoblastic lymphoma are the same disease entities at the morphologic and immunophenotypic levels and classified as either B- and T-cell lymphoblastic leukemia/lymphoma (B-ALL and T-ALL). T-ALL comprises 15% of paediatric and 25% of adult ALL cases. T cell transformation is a multi-step process in which different genetic alterations cooperate to alter the normal mechanisms that control cell growth, proliferation, survival, and differentiation during thymocyte development. In this context, constitutive activation of NOTCH1 signaling is the most prominent oncogenic pathway in T cell transformation. In addition, T-ALLs characteristically show the translocation and aberrant expression of transcription factor oncogenes. These oncogenic transcription factors include T-cell leukaemia homeobox protein 1 (TLX1 also known as HOX11), TLX3 (HOX11L2), LYL1, TAL1 and MLL.; drug: Cyclophosphamide [DR:D00287]\n Methotrexate [DR:D00142]\n Mercaptopurine [DR:D00161]\n Clofarabine [DR:D03546]\n Nelarabine [DR:D05134]\n Vincristine sulfate [DR:D02197] (Philadelphia chromosome-negative)\n Teniposide [DR:D02698]\n Doxorubicin hydrochloride [DR:D01275]\n Daunorubicin hydrochloride [DR:D01264]\n Mitoxantrone hydrochloride [DR:D02166]\n Asparaginase [DR:D02997]\n Pegaspargase [DR:D05387]\n Enocitabine [DR:D01633]\n Calaspargase pegol [DR:D10096]',
#  'metadata': {'name': 'T-cell acute lymphoblastic leukemia;\n T-cell acute lymphocytic leukemia',
#   'text': 'name: T-cell acute lymphoblastic leukemia;\n T-cell acute lymphocytic leukemia; category: Cancer; description: Acute lymphocytic leukemia (ALL) is a clonal stem cell malignancy of excessive lymphoblast proliferation. It is now understood that ALL and lymphoblastic lymphoma are the same disease entities at the morphologic and immunophenotypic levels and classified as either B- and T-cell lymphoblastic leukemia/lymphoma (B-ALL and T-ALL). T-ALL comprises 15% of paediatric and 25% of adult ALL cases. T cell transformation is a multi-step process in which different genetic alterations cooperate to alter the normal mechanisms that control cell growth, proliferation, survival, and differentiation during thymocyte development. In this context, constitutive activation of NOTCH1 signaling is the most prominent oncogenic pathway in T cell transformation. In addition, T-ALLs characteristically show the translocation and aberrant expression of transcription factor oncogenes. These oncogenic transcription factors include T-cell leukaemia homeobox protein 1 (TLX1 also known as HOX11), TLX3 (HOX11L2), LYL1, TAL1 and MLL.; drug: Cyclophosphamide [DR:D00287]\n Methotrexate [DR:D00142]\n Mercaptopurine [DR:D00161]\n Clofarabine [DR:D03546]\n Nelarabine [DR:D05134]\n Vincristine sulfate [DR:D02197] (Philadelphia chromosome-negative)\n Teniposide [DR:D02698]\n Doxorubicin hydrochloride [DR:D01275]\n Daunorubicin hydrochloride [DR:D01264]\n Mitoxantrone hydrochloride [DR:D02166]\n Asparaginase [DR:D02997]\n Pegaspargase [DR:D05387]\n Enocitabine [DR:D01633]\n Calaspargase pegol [DR:D10096]',
#   'gene': 'NOTCH1 (mutation) [HSA:4851] [KO:K02599]\n TAL1 (overexpression) [HSA:6886] [KO:K09068]\n TAL2 [HSA:6887] [KO:K09068]\n LYL1 (expression) [HSA:4066] [KO:K15604]\n MLL-ENL (translocation) [HSA:4297] [KO:K09186]\n HOX11 (translocation) [HSA:3195] [KO:K09340]\n MYC (translocation) [HSA:4609] [KO:K04377]\n LMO2 (translocation) [HSA:4005] [KO:K15612]\n HOX11L2 (translocation) [HSA:30012] [KO:K15607]\n PICALM-MLLT10 (translocation) [HSA:8028] [KO:K23588]',
#   'pathogen': nan,
#   'env_factor': nan,
#   'carcinogen': '*Thorium-232 and its decay products, administered intravenously as a colloidal dispersion of thorium232 dioxide\n *: Although this is a risk factor for ALL in general, the strength of association with different histological tumor types is not well understood.',
#   'drug': 'Cyclophosphamide [DR:D00287]\n Methotrexate [DR:D00142]\n Mercaptopurine [DR:D00161]\n Clofarabine [DR:D03546]\n Nelarabine [DR:D05134]\n Vincristine sulfate [DR:D02197] (Philadelphia chromosome-negative)\n Teniposide [DR:D02698]\n Doxorubicin hydrochloride [DR:D01275]\n Daunorubicin hydrochloride [DR:D01264]\n Mitoxantrone hydrochloride [DR:D02166]\n Asparaginase [DR:D02997]\n Pegaspargase [DR:D05387]\n Enocitabine [DR:D01633]\n Calaspargase pegol [DR:D10096]',
#   'comment': nan}}

# %%
disease_df = pd.DataFrame(disease_preprocess)
preprocessed_datasets.append(disease_df)
print(disease_df.shape)
disease_df.head()
# Out:
# (2577, 3)
#        id                                              input  \
# 0  H00001  name: B-cell acute lymphoblastic leukemia;\n B...
# 1  H00002  name: T-cell acute lymphoblastic leukemia;\n T...
# 2  H00003  name: Acute myeloid leukemia; category: Cancer...
# 3  H00004  name: Chronic myeloid leukemia; category: Canc...
# 4  H00005  name: Chronic lymphocytic leukemia; category: ...
#
#                                             metadata
# 0  {'name': 'B-cell acute lymphoblastic leukemia;...
# 1  {'name': 'T-cell acute lymphoblastic leukemia;...
# 2  {'name': 'Acute myeloid leukemia', 'text': 'na...
# 3  {'name': 'Chronic myeloid leukemia', 'text': '...
# 4  {'name': 'Chronic lymphocytic leukemia', 'text...

# %% [markdown]
# #### Kegg Medicus D-Group Data Preprocessing

# %%
raw_dgroup_df.shape
# Out:
# (2398, 13)

# %%
raw_dgroup_df.head()
# Out:
#      ENTRY CLASSIFICATION                                               NAME  \
# 0  DG00001         DGroup               Chlorhexidine\n TYPE        Chemical
# 1  DG00002         DGroup                Oxyquinoline\n TYPE        Chemical
# 2  DG00003         DGroup    Neomycin\n ABBR      NEO\n TYPE        Chemical
# 3  DG00004         DGroup                  Miconazole\n TYPE        Chemical
# 4  DG00005         DGroup  Tetracycline\n ABBR      TET\n TYPE        Che...
#
#   STEM  IMAGE                                             MEMBER  \
# 0  NaN    NaN  D07668  Chlorhexidine (INN)\n D00858  Chlorhex...
# 1  NaN    NaN  D05321  Oxyquinoline (USAN)\n D02414  Oxyquino...
# 2  NaN    NaN  D08260  Neomycin (INN)\n D01618  Neomycin sulf...
# 3  NaN    NaN  D00416  Miconazole (JP18/USP/INN)  <JP/US>\n D...
# 4  NaN    NaN  D00201  Tetracycline (JAN/USP/INN)\n D02122  T...
#
#                                                CLASS  \
# 0                                                NaN
# 1                                                NaN
# 2  Antibacterial\n DG01447  Aminoglycoside antibi...
# 3  Antifungal\n DG01883  Imidazole antifungal\n M...
# 4   Antibacterial\n DG01197  Tetracycline antibiotic
#
#                                               REMARK COMMENT  \
# 0  ATC code: A01AB03 B05CA02 D08AC02 D09AA12 R02A...     NaN
# 1          ATC code: A01AB07 D08AH03 G01AC30 R02AA14     NaN
# 2  ATC code: A01AB08 A07AA01 B05CA09 D06AX04 J01G...     NaN
# 3  ATC code: A01AB09 A07AC01 D01AC02 G01AF04 J02A...     NaN
# 4  ATC code: A01AB13 D06AA04 J01AA07 S01AA09 S02A...     NaN
#
#                                           ENTRY_link  \
# 0  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 1  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 2  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 3  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 4  <a href="https://www.kegg.jp/dbget-bin/www_bge...
#
#                                          MEMBER_link  \
# 0  <a href="http://togodb.biosciencedbc.jp/togodb...
# 1  <a href="http://togodb.biosciencedbc.jp/togodb...
# 2  <a href="http://togodb.biosciencedbc.jp/togodb...
# 3  <a href="http://togodb.biosciencedbc.jp/togodb...
# 4  <a href="http://togodb.biosciencedbc.jp/togodb...
#
#                                           CLASS_link  \
# 0                                                NaN
# 1                                                NaN
# 2  Antibacterial\n <a href="https://www.kegg.jp/d...
# 3  Antifungal\n <a href="https://www.kegg.jp/dbge...
# 4  Antibacterial\n <a href="https://www.kegg.jp/d...
#
#                                          REMARK_link
# 0  ATC code: <a href="https://www.kegg.jp/kegg-bi...
# 1  ATC code: <a href="https://www.kegg.jp/kegg-bi...
# 2  ATC code: <a href="https://www.kegg.jp/kegg-bi...
# 3  ATC code: <a href="https://www.kegg.jp/kegg-bi...
# 4  ATC code: <a href="https://www.kegg.jp/kegg-bi...

# %%
exclude = ['CLASSIFICATION','STEM','IMAGE','COMMENT','CLASS_link','ENTRY_link','REMARK_link','MEMBER_link']
clean_dgroup_df = raw_dgroup_df[[col for col in raw_dgroup_df.columns if col not in exclude]]

# %%
raw_dgroup_df.isna().sum()
# Out:
# ENTRY                0
# CLASSIFICATION       0
# NAME                 0
# STEM              2232
# IMAGE             2398
# MEMBER               0
# CLASS              570
# REMARK             966
# COMMENT           2387
# ENTRY_link           0
# MEMBER_link          0
# CLASS_link         570
# REMARK_link        966
# dtype: int64

# %%
clean_dgroup_df.head()
# Out:
#      ENTRY                                               NAME  \
# 0  DG00001               Chlorhexidine\n TYPE        Chemical
# 1  DG00002                Oxyquinoline\n TYPE        Chemical
# 2  DG00003    Neomycin\n ABBR      NEO\n TYPE        Chemical
# 3  DG00004                  Miconazole\n TYPE        Chemical
# 4  DG00005  Tetracycline\n ABBR      TET\n TYPE        Che...
#
#                                               MEMBER  \
# 0  D07668  Chlorhexidine (INN)\n D00858  Chlorhex...
# 1  D05321  Oxyquinoline (USAN)\n D02414  Oxyquino...
# 2  D08260  Neomycin (INN)\n D01618  Neomycin sulf...
# 3  D00416  Miconazole (JP18/USP/INN)  <JP/US>\n D...
# 4  D00201  Tetracycline (JAN/USP/INN)\n D02122  T...
#
#                                                CLASS  \
# 0                                                NaN
# 1                                                NaN
# 2  Antibacterial\n DG01447  Aminoglycoside antibi...
# 3  Antifungal\n DG01883  Imidazole antifungal\n M...
# 4   Antibacterial\n DG01197  Tetracycline antibiotic
#
#                                               REMARK
# 0  ATC code: A01AB03 B05CA02 D08AC02 D09AA12 R02A...
# 1          ATC code: A01AB07 D08AH03 G01AC30 R02AA14
# 2  ATC code: A01AB08 A07AA01 B05CA09 D06AX04 J01G...
# 3  ATC code: A01AB09 A07AC01 D01AC02 G01AF04 J02A...
# 4  ATC code: A01AB13 D06AA04 J01AA07 S01AA09 S02A...

# %%
#3
def row_to_dict(row):
    entry_id = row['ENTRY']
    name = row['NAME']
    class_item = row['CLASS']
    remark = row['REMARK']
    member = row['MEMBER']
    text = f"name: {name}; member: {member}; class: {class_item};  remark: {remark}"

    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "text": text,
                "name": name,
                "class": class_item
            }
        }

    return output_dict

# %%
dgroup_preprocess = convert_dataframe_to_list(clean_dgroup_df)
print(len(dgroup_preprocess))
dgroup_preprocess[0]
# Out:
# 2398
# {'id': 'DG00001',
#  'input': 'name: Chlorhexidine\n TYPE        Chemical; member: D07668  Chlorhexidine (INN)\n D00858  Chlorhexidine gluconate (JP18/USP)  <JP/US>\n D01345  Chlorhexidine hydrochloride (JP18/USP)\n D03463  Chlorhexidine phosphanilate (USAN)\n D07669  Chlorhexidine acetate (USP); class: nan;  remark: ATC code: A01AB03 B05CA02 D08AC02 D09AA12 R02AA05 S01AX09 S02AA09 S03AA04',
#  'metadata': {'text': 'name: Chlorhexidine\n TYPE        Chemical; member: D07668  Chlorhexidine (INN)\n D00858  Chlorhexidine gluconate (JP18/USP)  <JP/US>\n D01345  Chlorhexidine hydrochloride (JP18/USP)\n D03463  Chlorhexidine phosphanilate (USAN)\n D07669  Chlorhexidine acetate (USP); class: nan;  remark: ATC code: A01AB03 B05CA02 D08AC02 D09AA12 R02AA05 S01AX09 S02AA09 S03AA04',
#   'name': 'Chlorhexidine\n TYPE        Chemical',
#   'class': nan}}

# %%
dgroup_df = pd.DataFrame(dgroup_preprocess)
preprocessed_datasets.append(dgroup_df)
print(dgroup_df.shape)
dgroup_df.head()
# Out:
# (2398, 3)
#         id                                              input  \
# 0  DG00001  name: Chlorhexidine\n TYPE        Chemical; me...
# 1  DG00002  name: Oxyquinoline\n TYPE        Chemical; mem...
# 2  DG00003  name: Neomycin\n ABBR      NEO\n TYPE        C...
# 3  DG00004  name: Miconazole\n TYPE        Chemical; membe...
# 4  DG00005  name: Tetracycline\n ABBR      TET\n TYPE     ...
#
#                                             metadata
# 0  {'text': 'name: Chlorhexidine
#  TYPE        Che...
# 1  {'text': 'name: Oxyquinoline
#  TYPE        Chem...
# 2  {'text': 'name: Neomycin
#  ABBR      NEO
#  TYPE ...
# 3  {'text': 'name: Miconazole
#  TYPE        Chemic...
# 4  {'text': 'name: Tetracycline
#  ABBR      TET
#  T...

# %% [markdown]
# #### Kegg Medicus Environ Data Preprocessing

# %%
raw_environ_df.head()
# Out:
#   E number                   Name                    Category  \
# 0   E00001  Coptis rhizome (JP17)                  Crude drug
# 1   E00002    Evodia fruit (JP17)                  Crude drug
# 2   E00003         Saffron (JP17)  Crude drug; Medicinal herb
# 3   E00004         Agar (JP17/NF)                  Crude drug
# 4   E00005   Tragacanth (JP17/NF)                  Crude drug
#
#                                            Component  \
# 0  Berberine [CPD:C00757], Palmatine [CPD:C05315]...
# 1  Evodiamine [CPD:C09187], Rutecarpine [CPD:C092...
# 2  Crocin [CPD:C08589], Picrocrocin [CPD:C17055],...
# 3                               Agarose [CPD:C01399]
# 4  D-Galacturonic acid [CPD:C00333], Tragacanthic...
#
#                                               Source           Remark  \
# 0  Coptis japonica [TAX:3442], Coptis chinensis [...  Same as: D00092
# 1  Evodia rutaecarpa [TAX:354523], Evodia officin...  Same as: D00173
# 2                         Crocus sativus [TAX:82528]  Same as: D01030
# 3                        Gelidium amansii [TAX:2812]  Same as: D01032
# 4  Astragalus gummifer [TAX:339493], Leguminosae ...  Same as: D01033
#
#                                              Comment Other DBs
# 0  Ranunculaceae (buttercup family) Coptis rhizom...       NaN
# 1  Rutaceae (rue family) Evodia fruit\r\nMajor co...       NaN
# 2  Iridaceae (Iris family) Saffron chapiter\r\nMa...       NaN
# 3  Gelidiaceae Gelidium amansii mucous (freeze dr...       NaN
# 4  Fabaceae (pea family) Tragacanth stem exudatio...       NaN

# %%
raw_environ_df.shape
# Out:
# (850, 8)

# %%
exclude = ['Remark', 'Other DBs']
clean_environ_df = raw_environ_df[[col for col in raw_environ_df.columns if col not in exclude]]

# %%
raw_environ_df.isna().sum()
# Out:
# E number       0
# Name           0
# Category      12
# Component    306
# Source        22
# Remark       556
# Comment        9
# Other DBs    757
# dtype: int64

# %%
clean_environ_df.head()
# Out:
#   E number                   Name                    Category  \
# 0   E00001  Coptis rhizome (JP17)                  Crude drug
# 1   E00002    Evodia fruit (JP17)                  Crude drug
# 2   E00003         Saffron (JP17)  Crude drug; Medicinal herb
# 3   E00004         Agar (JP17/NF)                  Crude drug
# 4   E00005   Tragacanth (JP17/NF)                  Crude drug
#
#                                            Component  \
# 0  Berberine [CPD:C00757], Palmatine [CPD:C05315]...
# 1  Evodiamine [CPD:C09187], Rutecarpine [CPD:C092...
# 2  Crocin [CPD:C08589], Picrocrocin [CPD:C17055],...
# 3                               Agarose [CPD:C01399]
# 4  D-Galacturonic acid [CPD:C00333], Tragacanthic...
#
#                                               Source  \
# 0  Coptis japonica [TAX:3442], Coptis chinensis [...
# 1  Evodia rutaecarpa [TAX:354523], Evodia officin...
# 2                         Crocus sativus [TAX:82528]
# 3                        Gelidium amansii [TAX:2812]
# 4  Astragalus gummifer [TAX:339493], Leguminosae ...
#
#                                              Comment
# 0  Ranunculaceae (buttercup family) Coptis rhizom...
# 1  Rutaceae (rue family) Evodia fruit\r\nMajor co...
# 2  Iridaceae (Iris family) Saffron chapiter\r\nMa...
# 3  Gelidiaceae Gelidium amansii mucous (freeze dr...
# 4  Fabaceae (pea family) Tragacanth stem exudatio...

# %%
#4
def row_to_dict(row):
    entry_id = row['E number']
    name = row['Name']
    category = row['Category']
    component = row['Component']
    source = row['Source']
    comment = row['Comment']
    text = f"name: {name}; category: {category}; component: {comment} comment: {comment}; source: {source}"

    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "name": name, 
                "text": text,
                "component": component,
                
            }
        }

    return output_dict

# %%
environ_preprocess = convert_dataframe_to_list(clean_environ_df)
print(len(environ_preprocess))
environ_preprocess[0]
# Out:
# 850
# {'id': 'E00001',
#  'input': 'name: Coptis rhizome (JP17); category: Crude drug; component: Ranunculaceae (buttercup family) Coptis rhizome\r\nMajor component: Berberine [CPD:C00757] comment: Ranunculaceae (buttercup family) Coptis rhizome\r\nMajor component: Berberine [CPD:C00757]; source: Coptis japonica [TAX:3442], Coptis chinensis [TAX:261450], Coptis deltoidea [TAX:261449], Coptis teeta [TAX:261448]',
#  'metadata': {'name': 'Coptis rhizome (JP17)',
#   'text': 'name: Coptis rhizome (JP17); category: Crude drug; component: Ranunculaceae (buttercup family) Coptis rhizome\r\nMajor component: Berberine [CPD:C00757] comment: Ranunculaceae (buttercup family) Coptis rhizome\r\nMajor component: Berberine [CPD:C00757]; source: Coptis japonica [TAX:3442], Coptis chinensis [TAX:261450], Coptis deltoidea [TAX:261449], Coptis teeta [TAX:261448]',
#   'component': 'Berberine [CPD:C00757], Palmatine [CPD:C05315], Jateorrhizine [CPD:C09553], Coptisine [CPD:C16938], Worenine [CPD:C17083], Magnoflorine [CPD:C09581], Ferulic acid [CPD:C01494], Chlorogenic acid [CPD:C00852], Tetrahydroberberine [CPD:C03329], Tetrahydropalmatine [CPD:C02890]'}}

# %%
environ_df = pd.DataFrame(environ_preprocess)
preprocessed_datasets.append(environ_df)
print(environ_df.shape)
environ_df.head()
# Out:
# (850, 3)
#        id                                              input  \
# 0  E00001  name: Coptis rhizome (JP17); category: Crude d...
# 1  E00002  name: Evodia fruit (JP17); category: Crude dru...
# 2  E00003  name: Saffron (JP17); category: Crude drug; Me...
# 3  E00004  name: Agar (JP17/NF); category: Crude drug; co...
# 4  E00005  name: Tragacanth (JP17/NF); category: Crude dr...
#
#                                             metadata
# 0  {'name': 'Coptis rhizome (JP17)', 'text': 'nam...
# 1  {'name': 'Evodia fruit (JP17)', 'text': 'name:...
# 2  {'name': 'Saffron (JP17)', 'text': 'name: Saff...
# 3  {'name': 'Agar (JP17/NF)', 'text': 'name: Agar...
# 4  {'name': 'Tragacanth (JP17/NF)', 'text': 'name...

# %% [markdown]
# #### Kegg Medicus Network Data Preprocessing

# %%
raw_network_df.head()
# Out:
#     ENTRY                                               NAME  \
# 0  N00001                 EGF-EGFR-RAS-ERK signaling pathway
# 1  N00002  BCR-ABL fusion kinase to RAS-ERK signaling pat...
# 2  N00003  Mutation-activated KIT to RAS-ERK signaling pa...
# 3  N00004  Duplication or mutation-activated FLT3 to RAS-...
# 4  N00005  Mutation-activated MET to RAS-ERK signaling pa...
#
#                                           DEFINITION  \
# 0  EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> ME...
# 1  BCR-ABL -> GRB2 -> SOS -> RAS -> RAF -> MEK ->...
# 2    KIT* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 3   FLT3* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 4  MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ER...
#
#                                             EXPANDED  \
# 0  1950 -> 1956 -> 2885 -> (6654,6655) -> (3265,3...
# 1  (25v1,25v2) -> 2885 -> (6654,6655) -> (3265,38...
# 2  3815v1 -> 2885 -> (6654,6655) -> (3265,3845,48...
# 3  (2322v2,2322v1) -> 2885 -> (6654,6655) -> (326...
# 4  4233v1 -> 2885 -> (6654,6655) -> (3265,3845,48...
#
#                                                CLASS       TYPE  \
# 0  nt06210 ERK signaling\nnt06260 Colorectal canc...  Reference
# 1  nt06210 ERK signaling\nnt06276 Chronic myeloid...    Variant
# 2  nt06210 ERK signaling\nnt06275 Acute myeloid l...    Variant
# 3  nt06210 ERK signaling\nnt06275 Acute myeloid l...    Variant
# 4  nt06210 ERK signaling\nnt06263 Hepatocellular ...    Variant
#
#                                              DISEASE  \
# 0                                                NaN
# 1                   H00004  Chronic myeloid leukemia
# 2                     H00003  Acute myeloid leukemia
# 3                     H00003  Acute myeloid leukemia
# 4  H00048  Hepatocellular carcinoma\nH00021  Rena...
#
#                                                 GENE  \
# 0  1950  EGF; epidermal growth factor\n1956  EGFR...
# 1  25  ABL1; ABL proto-oncogene 1, non-receptor t...
# 2  3815  KIT; KIT proto-oncogene receptor tyrosin...
# 3  2322  FLT3; fms related tyrosine kinase 3\n288...
# 4  4233  MET; MET proto-oncogene, receptor tyrosi...
#
#                                              VARIANT METABOLITE  ...  \
# 0                                                NaN        NaN  ...
# 1  25v1 (BCR-ABL)  BCR-ABL1 fusion\n25v2 (BCR-ABL...        NaN  ...
# 2          3815v1 (KIT*)  KIT kinase domain mutation        NaN  ...
# 3  2322v2 (FLT3*)  FLT3 internal tandem duplicati...        NaN  ...
# 4          4233v1 (MET*)  MET kinase domain mutation        NaN  ...
#
#                                           ENTRY_link  \
# 0  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 1  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 2  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 3  <a href="https://www.kegg.jp/dbget-bin/www_bge...
# 4  <a href="https://www.kegg.jp/dbget-bin/www_bge...
#
#                                      DEFINITION_link  \
# 0  EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> ME...
# 1  BCR-ABL -> GRB2 -> SOS -> RAS -> RAF -> MEK ->...
# 2    KIT* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 3   FLT3* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 4  MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ER...
#
#                                        EXPANDED_link  \
# 0  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 1  (<a href="http://www.kegg.jp/dbget-bin/www_bge...
# 2  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 3  (<a href="http://www.kegg.jp/dbget-bin/www_bge...
# 4  <a href="http://www.kegg.jp/dbget-bin/www_bget...
#
#                                           CLASS_link  \
# 0  <a href="https://www.kegg.jp/network/nt06210">...
# 1  <a href="https://www.kegg.jp/network/nt06210">...
# 2  <a href="https://www.kegg.jp/network/nt06210">...
# 3  <a href="https://www.kegg.jp/network/nt06210">...
# 4  <a href="https://www.kegg.jp/network/nt06210">...
#
#                                         DISEASE_link  \
# 0                                                NaN
# 1  <a href="http://togodb.biosciencedbc.jp/entry/...
# 2  <a href="http://togodb.biosciencedbc.jp/entry/...
# 3  <a href="http://togodb.biosciencedbc.jp/entry/...
# 4  <a href="http://togodb.biosciencedbc.jp/entry/...
#
#                                            GENE_link  \
# 0  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 1  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 2  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 3  <a href="http://www.kegg.jp/dbget-bin/www_bget...
# 4  <a href="http://www.kegg.jp/dbget-bin/www_bget...
#
#                                         VARIANT_link METABOLITE_link  \
# 0                                                NaN             NaN
# 1  <a href="http://togodb.biosciencedbc.jp/togodb...             NaN
# 2  <a href="http://togodb.biosciencedbc.jp/togodb...             NaN
# 3  <a href="http://togodb.biosciencedbc.jp/togodb...             NaN
# 4  <a href="http://togodb.biosciencedbc.jp/togodb...             NaN
#
#   PERTURBANT_link                                     REFERENCE_link
# 0             NaN  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 1             NaN  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 2             NaN  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 3             NaN  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 4             NaN  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
#
# [5 rows x 22 columns]

# %%
raw_network_df.shape
# Out:
# (1241, 22)

# %%
exclude = ['ENTRY_link','VARIANT','METABOLITE','PERTURBANT','DEFINITION_link', 'EXPANDED_link', 'CLASS_link', 'DISEASE_link', 'GENE_link', 'VARIANT_link',
           'METABOLITE_link', 'PERTURBANT_link','REFERENCE_link']
clean_network_df = raw_network_df[[col for col in raw_network_df.columns if col not in exclude]]

# %%
clean_network_df.head()
# Out:
#     ENTRY                                               NAME  \
# 0  N00001                 EGF-EGFR-RAS-ERK signaling pathway
# 1  N00002  BCR-ABL fusion kinase to RAS-ERK signaling pat...
# 2  N00003  Mutation-activated KIT to RAS-ERK signaling pa...
# 3  N00004  Duplication or mutation-activated FLT3 to RAS-...
# 4  N00005  Mutation-activated MET to RAS-ERK signaling pa...
#
#                                           DEFINITION  \
# 0  EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> ME...
# 1  BCR-ABL -> GRB2 -> SOS -> RAS -> RAF -> MEK ->...
# 2    KIT* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 3   FLT3* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK
# 4  MET* -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ER...
#
#                                             EXPANDED  \
# 0  1950 -> 1956 -> 2885 -> (6654,6655) -> (3265,3...
# 1  (25v1,25v2) -> 2885 -> (6654,6655) -> (3265,38...
# 2  3815v1 -> 2885 -> (6654,6655) -> (3265,3845,48...
# 3  (2322v2,2322v1) -> 2885 -> (6654,6655) -> (326...
# 4  4233v1 -> 2885 -> (6654,6655) -> (3265,3845,48...
#
#                                                CLASS       TYPE  \
# 0  nt06210 ERK signaling\nnt06260 Colorectal canc...  Reference
# 1  nt06210 ERK signaling\nnt06276 Chronic myeloid...    Variant
# 2  nt06210 ERK signaling\nnt06275 Acute myeloid l...    Variant
# 3  nt06210 ERK signaling\nnt06275 Acute myeloid l...    Variant
# 4  nt06210 ERK signaling\nnt06263 Hepatocellular ...    Variant
#
#                                              DISEASE  \
# 0                                                NaN
# 1                   H00004  Chronic myeloid leukemia
# 2                     H00003  Acute myeloid leukemia
# 3                     H00003  Acute myeloid leukemia
# 4  H00048  Hepatocellular carcinoma\nH00021  Rena...
#
#                                                 GENE  \
# 0  1950  EGF; epidermal growth factor\n1956  EGFR...
# 1  25  ABL1; ABL proto-oncogene 1, non-receptor t...
# 2  3815  KIT; KIT proto-oncogene receptor tyrosin...
# 3  2322  FLT3; fms related tyrosine kinase 3\n288...
# 4  4233  MET; MET proto-oncogene, receptor tyrosi...
#
#                                            REFERENCE
# 0  PMID:17409820\nAUTHORS   Molina JR, Adjei AA\n...
# 1  PMID:10403855\nAUTHORS   Faderl S, Talpaz M, E...
# 2  PMID:23678293\nAUTHORS   Liang J, Wu YL, Chen ...
# 3  PMID:12951584\nAUTHORS   Stirewalt DL, Radich ...
# 4  PMID:14685170\nAUTHORS   Birchmeier C, Birchme...

# %%
raw_network_df.isna().sum()
# Out:
# ENTRY                0
# NAME                 0
# DEFINITION           0
# EXPANDED             0
# CLASS               24
# TYPE                 0
# DISEASE            361
# GENE                 4
# VARIANT            867
# METABOLITE         924
# PERTURBANT         662
# REFERENCE           76
# ENTRY_link           0
# DEFINITION_link      0
# EXPANDED_link        0
# CLASS_link          24
# DISEASE_link       361
# GENE_link            4
# VARIANT_link       867
# METABOLITE_link    924
# PERTURBANT_link    662
# REFERENCE_link      76
# dtype: int64

# %%
clean_network_df.columns
# Out:
# Index(['ENTRY', 'NAME', 'DEFINITION', 'EXPANDED', 'CLASS', 'TYPE', 'DISEASE',
#        'GENE', 'REFERENCE'],
#       dtype='object')

# %%
#5
def row_to_dict(row):
    entry_id = row['ENTRY']
    name = row['NAME']
    definition = row['DEFINITION']
    expanded = row['EXPANDED']
    item_class = row['CLASS']
    item_type = row['TYPE']
    disease = row['DISEASE']
    gene = row['GENE']
    text = f"name: {name}; definition: {definition}; expanded: {expanded}; class: {item_class}, type: {item_type}"

    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "name": name,
                "text": text,
                "name": name,
                "class": item_class,
                "comment": item_type,
                "disease": disease,
                "gene":gene
            }
        }

    return output_dict

# %%
network_preprocess = convert_dataframe_to_list(clean_network_df)
print(len(network_preprocess))
network_preprocess[0]
# Out:
# 1241
# {'id': 'N00001',
#  'input': 'name: EGF-EGFR-RAS-ERK signaling pathway; definition: EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1; expanded: 1950 -> 1956 -> 2885 -> (6654,6655) -> (3265,3845,4893) -> (369,673,5894) -> (5604,5605) -> (5594,5595) -> 595; class: nt06210 ERK signaling\nnt06260 Colorectal cancer\nnt06263 Hepatocellular carcinoma\nnt06265 Bladder cancer\nnt06266 Non-small cell lung cancer\nnt06268 Melanoma\nnt06270 Breast cancer\nnt06271 Endometrial cancer\nnt06273 Glioma\nnt06274 Thyroid cancer\nnt06276 Chronic myeloid leukemia\nnt06110 MAPK signaling (viruses and bacteria)\nnt06162 Hepatitis B virus (HBV)\nnt06163 Hepatitis C virus (HCV)\nnt06170 Influenza A virus (IAV)\nnt06167 Human cytomegalovirus (HCMV)\nnt06166 Human papillomavirus (HPV), type: Reference',
#  'metadata': {'name': 'EGF-EGFR-RAS-ERK signaling pathway',
#   'text': 'name: EGF-EGFR-RAS-ERK signaling pathway; definition: EGF -> EGFR -> GRB2 -> SOS -> RAS -> RAF -> MEK -> ERK -> CCND1; expanded: 1950 -> 1956 -> 2885 -> (6654,6655) -> (3265,3845,4893) -> (369,673,5894) -> (5604,5605) -> (5594,5595) -> 595; class: nt06210 ERK signaling\nnt06260 Colorectal cancer\nnt06263 Hepatocellular carcinoma\nnt06265 Bladder cancer\nnt06266 Non-small cell lung cancer\nnt06268 Melanoma\nnt06270 Breast cancer\nnt06271 Endometrial cancer\nnt06273 Glioma\nnt06274 Thyroid cancer\nnt06276 Chronic myeloid leukemia\nnt06110 MAPK signaling (viruses and bacteria)\nnt06162 Hepatitis B virus (HBV)\nnt06163 Hepatitis C virus (HCV)\nnt06170 Influenza A virus (IAV)\nnt06167 Human cytomegalovirus (HCMV)\nnt06166 Human papillomavirus (HPV), type: Reference',
#   'class': 'nt06210 ERK signaling\nnt06260 Colorectal cancer\nnt06263 Hepatocellular carcinoma\nnt06265 Bladder cancer\nnt06266 Non-small cell lung cancer\nnt06268 Melanoma\nnt06270 Breast cancer\nnt06271 Endometrial cancer\nnt06273 Glioma\nnt06274 Thyroid cancer\nnt06276 Chronic myeloid leukemia\nnt06110 MAPK signaling (viruses and bacteria)\nnt06162 Hepatitis B virus (HBV)\nnt06163 Hepatitis C virus (HCV)\nnt06170 Influenza A virus (IAV)\nnt06167 Human cytomegalovirus (HCMV)\nnt06166 Human papillomavirus (HPV)',
#   'comment': 'Reference',
#   'disease': nan,
#   'gene': '1950  EGF; epidermal growth factor\n1956  EGFR; epidermal growth factor receptor\n2885  GRB2; growth factor receptor bound protein 2\n6654  SOS1; SOS Ras/Rac guanine nucleotide exchange factor 1\n6655  SOS2; SOS Ras/Rho guanine nucleotide exchange factor 2\n3265  HRAS; HRas proto-oncogene, GTPase\n3845  KRAS; KRAS proto-oncogene, GTPase\n4893  NRAS; NRAS proto-oncogene, GTPase\n369  ARAF; A-Raf proto-oncogene, serine/threonine kinase\n673  BRAF; B-Raf proto-oncogene, serine/threonine kinase\n5894  RAF1; Raf-1 proto-oncogene, serine/threonine kinase\n5604  MAP2K1; mitogen-activated protein kinase kinase 1\n5605  MAP2K2; mitogen-activated protein kinase kinase 2\n5594  MAPK1; mitogen-activated protein kinase 1\n5595  MAPK3; mitogen-activated protein kinase 3\n595  CCND1; cyclin D1'}}

# %%
network_df = pd.DataFrame(network_preprocess)
preprocessed_datasets.append(network_df)
print(network_df.shape)
network_df.head()
# Out:
# (1241, 3)
#        id                                              input  \
# 0  N00001  name: EGF-EGFR-RAS-ERK signaling pathway; defi...
# 1  N00002  name: BCR-ABL fusion kinase to RAS-ERK signali...
# 2  N00003  name: Mutation-activated KIT to RAS-ERK signal...
# 3  N00004  name: Duplication or mutation-activated FLT3 t...
# 4  N00005  name: Mutation-activated MET to RAS-ERK signal...
#
#                                             metadata
# 0  {'name': 'EGF-EGFR-RAS-ERK signaling pathway',...
# 1  {'name': 'BCR-ABL fusion kinase to RAS-ERK sig...
# 2  {'name': 'Mutation-activated KIT to RAS-ERK si...
# 3  {'name': 'Duplication or mutation-activated FL...
# 4  {'name': 'Mutation-activated MET to RAS-ERK si...

# %% [markdown]
# #### Kegg Medicus Variant Data Preprocessing

# %%
raw_variant_df.head()
# Out:
#      ENTRY                NAME  \
# 0  10026v1     PIGK deficiency
# 1    100v1      ADA deficiency
# 2  10133v1       OPTN mutation
# 3  10195v1     ALG3 deficiency
# 4   1019v1  CDK4 amplification
#
#                                                 GENE  \
# 0  PIGK  phosphatidylinositol glycan anchor biosy...
# 1               ADA  adenosine deaminase [KO:K01488]
# 2                       OPTN  optineurin [KO:K19946]
# 3  ALG3  ALG3 alpha-1,3- mannosyltransferase [KO:...
# 4        CDK4  cyclin dependent kinase 4 [KO:K02089]
#
#                                      ORGANISM  \
# 0  hsa_var Human gene variants (Homo sapiens)
# 1  hsa_var Human gene variants (Homo sapiens)
# 2  hsa_var Human gene variants (Homo sapiens)
# 3  hsa_var Human gene variants (Homo sapiens)
# 4  hsa_var Human gene variants (Homo sapiens)
#
#                                            VARIATION  \
# 0                         mutations\nOmimVar: 605087
# 1  mutations\nOmimVar: 608958\nDRUG_TARGET Elapeg...
# 2                          mutations\nOmimVar: 10133
# 3                         mutations\nOmimVar: 608750
# 4  amplification\nClinVar: 268075 150740\ndbVar: ...
#
#                                              NETWORK  \
# 0                                                NaN
# 1                                                NaN
# 2  nt06421  Mitophagy\nnt06464  Amyotrophic later...
# 3                                                NaN
# 4               nt06230  Cell cycle\nnt06273  Glioma
#
#                                              ELEMENT  \
# 0                                                NaN
# 1                                                NaN
# 2  N01138  Mutation-inactivated OPTN to PINK-Park...
# 3                                                NaN
# 4          N00072  Amplified CDK4 to cell cycle G1/S
#
#                                            REFERENCE  \
# 0  PMID:32220290\nAUTHORS   Nguyen TTM, Murakami ...
# 1                                                NaN
# 2  PMID:20428114\nAUTHORS   Maruyama H, Morino H,...
# 3  PMID:15108280\nAUTHORS   Denecke J, Kranz C, K...
# 4  PMID:7987821\nAUTHORS   Schmidt EE, Ichimura K...
#
#                                           ENTRY_link  \
# 0  <a href="https://www.genome.jp/dbget-bin/www_b...
# 1  <a href="https://www.genome.jp/dbget-bin/www_b...
# 2  <a href="https://www.genome.jp/dbget-bin/www_b...
# 3  <a href="https://www.genome.jp/dbget-bin/www_b...
# 4  <a href="https://www.genome.jp/dbget-bin/www_b...
#
#                                            GENE_link  \
# 0  PIGK  phosphatidylinositol glycan anchor biosy...
# 1  ADA  adenosine deaminase [KO:<a href="http://w...
# 2  OPTN  optineurin [KO:<a href="http://www.kegg....
# 3  ALG3  ALG3 alpha-1,3- mannosyltransferase [KO:...
# 4  CDK4  cyclin dependent kinase 4 [KO:<a href="h...
#
#                                       VARIATION_link  \
# 0  mutations\nOmimVar: <a href="https://omim.org/...
# 1  mutations\nOmimVar: <a href="https://omim.org/...
# 2  mutations\nOmimVar: <a href="https://omim.org/...
# 3  mutations\nOmimVar: <a href="https://omim.org/...
# 4  amplification\nClinVar: <a href="https://www.n...
#
#                                         NETWORK_link  \
# 0                                                NaN
# 1                                                NaN
# 2  <a href="http://togodb.biosciencedbc.jp/togodb...
# 3                                                NaN
# 4  <a href="http://togodb.biosciencedbc.jp/togodb...
#
#                                         ELEMENT_link  \
# 0                                                NaN
# 1                                                NaN
# 2  <a href="http://togodb.biosciencedbc.jp/togodb...
# 3                                                NaN
# 4  <a href="http://togodb.biosciencedbc.jp/togodb...
#
#                                       REFERENCE_link
# 0  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 1                                                NaN
# 2  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 3  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...
# 4  PMID:<a href="https://pubmed.ncbi.nlm.nih.gov/...

# %%
raw_variant_df.shape
# Out:
# (458, 14)

# %%
raw_variant_df.isna().sum()
# Out:
# ENTRY               0
# NAME                0
# GENE                0
# ORGANISM            0
# VARIATION           0
# NETWORK           210
# ELEMENT           198
# REFERENCE          20
# ENTRY_link          0
# GENE_link           0
# VARIATION_link      0
# NETWORK_link      210
# ELEMENT_link      198
# REFERENCE_link     20
# dtype: int64

# %%
exclude = ['ENTRY_link', 'NETWORK_link', 'GENE_link','ORGANISM', 'VARIATION_link',
           'ELEMENT_link', 'REFERENCE_link']
clean_variant_df = raw_variant_df[[col for col in raw_variant_df.columns if col not in exclude]]

# %%
clean_variant_df.head()
# Out:
#      ENTRY                NAME  \
# 0  10026v1     PIGK deficiency
# 1    100v1      ADA deficiency
# 2  10133v1       OPTN mutation
# 3  10195v1     ALG3 deficiency
# 4   1019v1  CDK4 amplification
#
#                                                 GENE  \
# 0  PIGK  phosphatidylinositol glycan anchor biosy...
# 1               ADA  adenosine deaminase [KO:K01488]
# 2                       OPTN  optineurin [KO:K19946]
# 3  ALG3  ALG3 alpha-1,3- mannosyltransferase [KO:...
# 4        CDK4  cyclin dependent kinase 4 [KO:K02089]
#
#                                            VARIATION  \
# 0                         mutations\nOmimVar: 605087
# 1  mutations\nOmimVar: 608958\nDRUG_TARGET Elapeg...
# 2                          mutations\nOmimVar: 10133
# 3                         mutations\nOmimVar: 608750
# 4  amplification\nClinVar: 268075 150740\ndbVar: ...
#
#                                              NETWORK  \
# 0                                                NaN
# 1                                                NaN
# 2  nt06421  Mitophagy\nnt06464  Amyotrophic later...
# 3                                                NaN
# 4               nt06230  Cell cycle\nnt06273  Glioma
#
#                                              ELEMENT  \
# 0                                                NaN
# 1                                                NaN
# 2  N01138  Mutation-inactivated OPTN to PINK-Park...
# 3                                                NaN
# 4          N00072  Amplified CDK4 to cell cycle G1/S
#
#                                            REFERENCE
# 0  PMID:32220290\nAUTHORS   Nguyen TTM, Murakami ...
# 1                                                NaN
# 2  PMID:20428114\nAUTHORS   Maruyama H, Morino H,...
# 3  PMID:15108280\nAUTHORS   Denecke J, Kranz C, K...
# 4  PMID:7987821\nAUTHORS   Schmidt EE, Ichimura K...

# %%
clean_variant_df.columns
# Out:
# Index(['ENTRY', 'NAME', 'GENE', 'VARIATION', 'NETWORK', 'ELEMENT',
#        'REFERENCE'],
#       dtype='object')

# %%
#6
def row_to_dict(row):
    entry_id = row['ENTRY']
    name = row['NAME']
    gene = row['GENE']
    variation = row['VARIATION']
    network = row['NETWORK']
    element = row['ELEMENT']
    reference = row['REFERENCE']
    text = f"name: {name}; gene: {gene}; variation: {variation}; network{network}; element{element}"

    output_dict = {
            "id": entry_id,
            "input": text,
            "metadata": {
                "name": name,
                "text": text,
                "network": network,
                "element": element,
                "reference": reference
            }
        }

    return output_dict

# %%
variant_preprocess = convert_dataframe_to_list(clean_variant_df)
print(len(variant_preprocess))
variant_preprocess[0]
# Out:
# 458
# {'id': '10026v1',
#  'input': 'name: PIGK deficiency; gene: PIGK  phosphatidylinositol glycan anchor biosynthesis class K [KO:K05290]; variation: mutations\nOmimVar: 605087; networknan; elementnan',
#  'metadata': {'name': 'PIGK deficiency',
#   'text': 'name: PIGK deficiency; gene: PIGK  phosphatidylinositol glycan anchor biosynthesis class K [KO:K05290]; variation: mutations\nOmimVar: 605087; networknan; elementnan',
#   'network': nan,
#   'element': nan,
#   'reference': 'PMID:32220290\nAUTHORS   Nguyen TTM, Murakami Y, Mobilio S, Niceta M, Zampino G, Philippe C, Moutton S, Zaki MS, James KN, Musaev D, Mu W, Baranano K, Nance JR, Rosenfeld JA, Braverman N, Ciolfi A, Millan F, Person RE, Bruel AL, Thauvin-Robinet C, Ververi A, DeVile C, Male A, Efthymiou S, Maroofian R, Houlden H, Maqbool S, Rahman F, Baratang NV, Rousseau J, St-Denis A, Elrick MJ, Anselm I, Rodan LH, Tartaglia M, Gleeson J, Kinoshita T, Campeau PM\nTITLE     Bi-allelic Variants in the GPI Transamidase Subunit PIGK Cause a Neurodevelopmental Syndrome with Hypotonia, Cerebellar Atrophy, and Epilepsy.\nJOURNAL   Am J Hum Genet 106:484-495 (2020)\nDOI:10.1016/j.ajhg.2020.03.001'}}

# %%
variant_df = pd.DataFrame(variant_preprocess)
preprocessed_datasets.append(variant_df)
print(variant_df.shape)
variant_df.head()
# Out:
# (458, 3)
#         id                                              input  \
# 0  10026v1  name: PIGK deficiency; gene: PIGK  phosphatidy...
# 1    100v1  name: ADA deficiency; gene: ADA  adenosine dea...
# 2  10133v1  name: OPTN mutation; gene: OPTN  optineurin [K...
# 3  10195v1  name: ALG3 deficiency; gene: ALG3  ALG3 alpha-...
# 4   1019v1  name: CDK4 amplification; gene: CDK4  cyclin d...
#
#                                             metadata
# 0  {'name': 'PIGK deficiency', 'text': 'name: PIG...
# 1  {'name': 'ADA deficiency', 'text': 'name: ADA ...
# 2  {'name': 'OPTN mutation', 'text': 'name: OPTN ...
# 3  {'name': 'ALG3 deficiency', 'text': 'name: ALG...
# 4  {'name': 'CDK4 amplification', 'text': 'name: ...

# %% [markdown]
# ### Data Preprocessing (Creating Embeddings)

# %%
index_data = []

# %%
def get_embedding(text):
    return embed.embed_documents(text)[0]

# %%
for df in preprocessed_datasets:
    print(f"indexing {df.shape}")
    df['values'] = df['input'].apply(get_embedding)
# Out:
# indexing (11938, 3)
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIError: The server had an error while processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID de0796e13eb9f6a9de50ab52230c7013 in your message.) {
#   "error": {
#     "message": "The server had an error while processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID de0796e13eb9f6a9de50ab52230c7013 in your message.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# }
#  500 {'error': {'message': 'The server had an error while processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID de0796e13eb9f6a9de50ab52230c7013 in your message.)', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Sat, 21 Oct 2023 22:49:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '366', 'Connection': 'keep-alive', 'access-control-allow-origin': '*', 'openai-organization': 'telkom-rqoajs', 'openai-processing-ms': '30017', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=15724800; includeSubDomains', 'x-ratelimit-limit-requests': '3000', 'x-ratelimit-limit-tokens': '1000000', 'x-ratelimit-remaining-requests': '2999', 'x-ratelimit-remaining-tokens': '999881', 'x-ratelimit-reset-requests': '20ms', 'x-ratelimit-reset-tokens': '7ms', 'x-request-id': 'de0796e13eb9f6a9de50ab52230c7013', 'CF-Cache-Status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': '819d0cb8c8490392-JNB', 'alt-svc': 'h3=":443"; ma=86400'}.
# indexing (2577, 3)
# indexing (2398, 3)
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/embeddings (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)'))).
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/embeddings (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)'))).
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')).
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')).
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)).
# indexing (850, 3)
# indexing (1241, 3)
# indexing (458, 3)

# %%
drugs_index = drugs_df.drop(['input'], axis=1)
drugs_dataset = pd.DataFrame.to_csv(drugs_index)
#with open('index_datasets/drugs.csv', 'w') as f: 
#    f.write(drugs_dataset)
index_data.append(drugs_index)
drugs_index.head()
# Out:
#        id                                           metadata  \
# 0  D00001  {'name': 'Water (JP18/USP);
# Purified water (JP...
# 1  D00002  {'name': 'Nadide (JAN/USAN/INN);
# Nicotinamide ...
# 2  D00003  {'name': 'Oxygen (JP18/USP)', 'text': 'name: O...
# 3  D00004  {'name': 'Carbon dioxide (JP18/USP);
# Carbon di...
# 4  D00005  {'name': 'Flavin adenine dinucleotide (JAN);
# A...
#
#                                               values
# 0  [-0.006311894406848522, -0.02489179188784771, ...
# 1  [-0.006311894406848522, -0.02489179188784771, ...
# 2  [-0.00636011841067576, -0.024926392883966173, ...
# 3  [-0.006311894406848522, -0.02489179188784771, ...
# 4  [-0.006311894406848522, -0.02489179188784771, ...

# %%
disease_index = disease_df.drop(['input'], axis=1)
disease_dataset = pd.DataFrame.to_csv(disease_index)
#with open('index_datasets/disease.csv', 'w') as f: 
#    f.write(disease_dataset)
index_data.append(disease_index)
disease_index.head()
# Out:
#        id                                           metadata  \
# 0  H00001  {'name': 'B-cell acute lymphoblastic leukemia;...
# 1  H00002  {'name': 'T-cell acute lymphoblastic leukemia;...
# 2  H00003  {'name': 'Acute myeloid leukemia', 'text': 'na...
# 3  H00004  {'name': 'Chronic myeloid leukemia', 'text': '...
# 4  H00005  {'name': 'Chronic lymphocytic leukemia', 'text...
#
#                                               values
# 0  [-0.00638153408315556, -0.024893257889223787, ...
# 1  [-0.006311894406848522, -0.02489179188784771, ...
# 2  [-0.006311894406848522, -0.02489179188784771, ...
# 3  [-0.006348727372756122, -0.02492023854670328, ...
# 4  [-0.006311894406848522, -0.02489179188784771, ...

# %%
dgroup_index = dgroup_df.drop(['input'], axis=1)
dgroup_dataset = pd.DataFrame.to_csv(dgroup_index)
#with open('index_datasets/dgroup.csv', 'w') as f: 
#   f.write(dgroup_dataset)
index_data.append(dgroup_index)
dgroup_index.head()
# Out:
#         id                                           metadata  \
# 0  DG00001  {'text': 'name: Chlorhexidine
#  TYPE        Che...
# 1  DG00002  {'text': 'name: Oxyquinoline
#  TYPE        Chem...
# 2  DG00003  {'text': 'name: Neomycin
#  ABBR      NEO
#  TYPE ...
# 3  DG00004  {'text': 'name: Miconazole
#  TYPE        Chemic...
# 4  DG00005  {'text': 'name: Tetracycline
#  ABBR      TET
#  T...
#
#                                               values
# 0  [-0.006311894406848522, -0.02489179188784771, ...
# 1  [-0.006341026706393906, -0.024902941958120584,...
# 2  [-0.006348727372756122, -0.02492023854670328, ...
# 3  [-0.006380894490020517, -0.024877912481013318,...
# 4  [-0.006348727372756122, -0.02492023854670328, ...

# %%
environ_index = environ_df.drop(['input'], axis=1)
environ_dataset = pd.DataFrame.to_csv(environ_index)
#with open('index_datasets/environ.csv', 'w') as f: 
#    f.write(environ_dataset)
index_data.append(environ_index)
environ_index.head()
# Out:
#        id                                           metadata  \
# 0  E00001  {'name': 'Coptis rhizome (JP17)', 'text': 'nam...
# 1  E00002  {'name': 'Evodia fruit (JP17)', 'text': 'name:...
# 2  E00003  {'name': 'Saffron (JP17)', 'text': 'name: Saff...
# 3  E00004  {'name': 'Agar (JP17/NF)', 'text': 'name: Agar...
# 4  E00005  {'name': 'Tragacanth (JP17/NF)', 'text': 'name...
#
#                                               values
# 0  [-0.006311894406848522, -0.02489179188784771, ...
# 1  [-0.006311894406848522, -0.02489179188784771, ...
# 2  [-0.006311894406848522, -0.02489179188784771, ...
# 3  [-0.00636011841067576, -0.024926392883966173, ...
# 4  [-0.006311894406848522, -0.02489179188784771, ...

# %%
variant_index = variant_df.drop(['input'], axis=1)
variant_dataset = pd.DataFrame.to_csv(variant_index)
#with open('index_datasets/variant.csv', 'w') as f: 
#    f.write(variant_dataset)
index_data.append(variant_index)
variant_index.head()
# Out:
#         id                                           metadata  \
# 0  10026v1  {'name': 'PIGK deficiency', 'text': 'name: PIG...
# 1    100v1  {'name': 'ADA deficiency', 'text': 'name: ADA ...
# 2  10133v1  {'name': 'OPTN mutation', 'text': 'name: OPTN ...
# 3  10195v1  {'name': 'ALG3 deficiency', 'text': 'name: ALG...
# 4   1019v1  {'name': 'CDK4 amplification', 'text': 'name: ...
#
#                                               values
# 0  [-0.006311894406848522, -0.02489179188784771, ...
# 1  [-0.00636011841067576, -0.024926392883966173, ...
# 2  [-0.006311894406848522, -0.02489179188784771, ...
# 3  [-0.00636011841067576, -0.024926392883966173, ...
# 4  [-0.006311894406848522, -0.02489179188784771, ...

# %%
network_index =  network_df.drop(['input'], axis=1)
network_dataset = pd.DataFrame.to_csv(network_index)
index_data.append
#with open('index_datasets/network.csv', 'w') as f: 
#    f.write(network_dataset)
index_data.append(network_index)
network_index.head()
# Out:
#        id                                           metadata  \
# 0  N00001  {'name': 'EGF-EGFR-RAS-ERK signaling pathway',...
# 1  N00002  {'name': 'BCR-ABL fusion kinase to RAS-ERK sig...
# 2  N00003  {'name': 'Mutation-activated KIT to RAS-ERK si...
# 3  N00004  {'name': 'Duplication or mutation-activated FL...
# 4  N00005  {'name': 'Mutation-activated MET to RAS-ERK si...
#
#                                               values
# 0  [-0.006311894406848522, -0.02489179188784771, ...
# 1  [-0.006306162547569985, -0.02492137430814508, ...
# 2  [-0.006311894406848522, -0.02489179188784771, ...
# 3  [-0.006311894406848522, -0.02489179188784771, ...
# 4  [-0.006306162547569985, -0.02492137430814508, ...

# %% [markdown]
# ### Data Storage

# %%
index_name = "kegg-medicus-database-index"

# %%
import pinecone

pinecone_api_key = os.getenv('PINECONE_API_KEY')

pinecone.init(
    api_key=os.environ['PINECONE_API_KEY'],
    environment='gcp-starter'
)

if index_name not in pinecone.list_indexes():
    # we create a new index
    pinecone.create_index(
        name=index_name,
        metric='dotproduct',
        dimension= len(result[0])  # 1536 dim of text-embedding-ada-002
    )
# Out:
# c:\Users\katle\anaconda3\envs\nlp_env\Lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
kegg_medicus_index = pinecone.GRPCIndex(index_name)
kegg_medicus_index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 0}},
#  'total_vector_count': 0}

# %%
for df in index_data:
    kegg_medicus_index.upsert_from_dataframe(df, batch_size=100)
# Out:
# sending upsert requests:   0%|          | 0/11938 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/120 [00:00<?, ?it/s]
# sending upsert requests:   0%|          | 0/2577 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/26 [00:00<?, ?it/s]
# sending upsert requests:   0%|          | 0/2398 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/24 [00:00<?, ?it/s]
# sending upsert requests:   0%|          | 0/850 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/9 [00:00<?, ?it/s]
# sending upsert requests:   0%|          | 0/458 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/5 [00:00<?, ?it/s]
# sending upsert requests:   0%|          | 0/1241 [00:00<?, ?it/s]
# collecting async responses:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
kegg_medicus_index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.19462,
#  'namespaces': {'': {'vector_count': 19462}},
#  'total_vector_count': 19462}
